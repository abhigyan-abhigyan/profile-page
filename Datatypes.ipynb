# %% [markdown]
# <a href="https://colab.research.google.com/github/abhigyan-abhigyan/profile-page/blob/main/Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %% [markdown]
# **Datatypes**

# %%
name='mike'

type(name)
# Out:
# str

# %%
name=input('enter your name')
print('welcome', name)
name
# Out:
# enter your nameAbhigyan
# welcome Abhigyan
# 'Abhigyan'

# %%
name=input('enter your name')
print('welcome', name)
name
type(name)
# Out:
# enter your nameabhigyan
# welcome abhigyan
# 'abhigyan'

# %%
a = True
b= 'true'
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# **Typecasting**

# %% [markdown]
# accuracy: 91.2%

# %%
acc=91.2
print(acc)
print(type(acc))
# Out:
# 91.2
# <class 'float'>

# %%
int(acc)
type(acc)
type(int(acc))
# Out:
# int

# %%
var=2
type(var)
# Out:
# int

# %%
var1= float(var)
print(type(var1))
var1
# Out:
# <class 'float'>
# 2.0

# %%
var=2.9
var_int=int(var)
print(var_int)
# Out:
# 2

# %%
var_new="2.3"
type(var_new)
var_1=float(var_new)
var_new=int(var_1)
type(var_new)
# Out:
# int

# %%
var="7.8"

float(var)
int(float(var))
# Out:
# 7

# %%
#string to int for float variable

string_var='hello'
print(string_var[0])
print(string_var[1])
print(string_var[2])

print(string_var[-3])
print(string_var[-1])
print(string_var[5]) #string len is 4 hence 5 will show an error
# Out:
# h
# e
# l
# l
# o
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-291/3638811866.py in <cell line: 0>()
#       8 print(string_var[-3])
#       9 print(string_var[-1])
# ---> 10 print(string_var[5])
#
# IndexError: string index out of range
